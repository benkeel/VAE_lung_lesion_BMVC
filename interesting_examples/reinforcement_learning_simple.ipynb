# %% [markdown]
# <a href="https://colab.research.google.com/github/benkeel/VAE_lung_lesion_BMVC/blob/main/interesting_examples/reinforcement_learning_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time
import matplotlib.pyplot as plt


world_states = ["A", "B"]

number_of_iterations = 25
number_of_timesteps = 50

success_list = []

class Agent:
    def __init__(self):
        self.learner_agent = {"A": ["action1", "action2"], "B": ["action1", "action2"]}

    def select_action(self, current_world_state):
        action = random.choice(self.learner_agent[current_world_state])
        return action
    def receive_reward(self, current_world_state, action):
        self.learner_agent[current_world_state].append(action)
        # Placeholder function for receiving reward
        #print("NEw learner agent for ", agent, self.learner_agent)
        pass

agent1 = Agent()
agent2 = Agent()

action1_total = 0
action2_total = 0


for iteration in range(number_of_iterations):
    success_rate = 0
    number_incorrect = 0
    for t in range(number_of_timesteps):
        current_world_state = random.choice(world_states)
        #print("Current world state:", current_world_state)

        agent1_action = agent1.select_action(current_world_state)
        agent2_action = agent2.select_action(current_world_state)

        if agent1_action == agent2_action:
            #print("Agents successfully matched actions!")
            if agent1_action == "action1":
                action1_total += 1
            if agent1_action == "action2":
                action2_total += 1
            agent1.receive_reward(current_world_state, agent1_action)
            agent2.receive_reward(current_world_state, agent1_action)
            success_rate += 1
            # Both agents receive a reward for successful communication
        else:
            number_incorrect += 1
            #print("Agents failed to match actions!")

        time.sleep(0.01)

    #print("Success rate for iteration:", success_rate / number_of_timesteps)
    success_list.append(success_rate/number_of_timesteps)


print("Number incorrect on last iteration", number_incorrect)
print("Totals of action 1 vs action 2", action1_total, action2_total)
print("Percentage of action 1", action1_total / (action1_total + action2_total))


plt.plot(range(1, number_of_iterations + 1), success_list)
plt.xlabel('Iteration')
plt.ylabel('Success Rate')
plt.title('Success Rate at Each Iteration')
plt.show()
print(success_list)
# Out:
# Number incorrect on last iteration 0
# Totals of action 1 vs action 2 5 1174
# Percentage of action 1 0.004240882103477523
# [0.72, 0.8, 0.92, 0.86, 0.94, 0.88, 0.96, 0.96, 0.98, 0.96, 0.92, 0.96, 0.98, 0.98, 0.98, 0.96, 0.98, 0.96, 0.96, 1.0, 1.0, 0.98, 0.96, 0.98, 1.0]

# %%
for i in range(100):
  print(agent2.select_action())
# Out:
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# action1
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# action2
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# action2
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A
# A

# %%
 learner_agent = {"A": ["action1", "action2"], "B": ["action1", "action2"]}
 learner_agent["B"]
# Out:
# ['action1', 'action2']

# %%
for i in range(100):
  current_world_state = "B"
  learner_agent = {"A": ["action1", "action2"], "B": ["action1", "action2"]}
  print(random.choice(learner_agent[current_world_state]))
# Out:
# action2
# action2
# action1
# action1
# action1
# action2
# action2
# action1
# action1
# action2
# action2
# action1
# action2
# action1
# action2
# action1
# action2
# action1
# action1
# action1
# action1
# action2
# action1
# action1
# action1
# action1
# action1
# action1
# action2
# action1
# action2
# action1
# action1
# action2
# action2
# action1
# action2
# action1
# action2
# action2
# action1
# action2
# action2
# action1
# action1
# action2
# action2
# action1
# action1
# action1
# action1
# action2
# action1
# action1
# action2
# action2
# action2
# action1
# action2
# action1
# action2
# action2
# action2
# action1
# action2
# action1
# action2
# action1
# action2
# action1
# action2
# action1
# action1
# action2
# action2
# action2
# action2
# action1
# action1
# action1
# action2
# action2
# action1
# action2
# action2
# action1
# action1
# action2
# action1
# action1
# action2
# action2
# action1
# action2
# action2
# action1
# action2
# action2
# action2
# action2
